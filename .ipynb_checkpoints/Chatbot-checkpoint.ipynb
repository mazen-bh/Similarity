# %%
import nltk
import string
import pandas as pd
import nlp_utils as nu
import matplotlib.pyplot as plt
# Loading necessary libraries
import json

# %%
df = pd.read_json('intents.json', orient='columns')
df2 = pd.read_json('intents.json', orient='columns')
df3 = pd.read_json('intents.json', orient='columns')

# %%
df = df.drop(columns=['context_set'])
df2 = df2.drop(columns=['context_set'])
df3 = df3.drop(columns=['context_set'])

# %%
df =df.drop(columns=['tag'])
df2 =df2.drop(columns=['tag'])
df3 =df3.drop(columns=['tag'])

# %%
df3
# Out:
#                                              patterns  \
# 0   [Hi there, Is anyone there?, Hey, Hola, Hello,...
# 1   [What is your name?, what are you?, who are yo...
# 2   [Bye, See you later, Goodbye, Nice chatting to...
# 3   [Thanks, Thank you, That's helpful, Awesome, t...
# 4   [How can you help me?, What can you do?, What ...
# ..                                                ...
# 66  [what is a html entity, what are html entities...
# 67  [what does an <abbr> tag do, what is <abbr>, t...
# 68  [how do you set the size of a column, how can ...
# 69  [how do i change the height of a row, tell me ...
# 70  [tell me about the <dl> tag, what is the <dl> ...
#
#                                             responses
# 0   [Hello, I'm sure you will love this course, Ha...
# 1   [Hi, I'm  BoTrainer, I'm BoTrainer , Call me B...
# 2   [Have a lovely day!, Have a nice studying time...
# 3   [Happy to help!, Any time!, My pleasure, Do en...
# 4   [I can answer your questions and clear your mi...
# ..                                                ...
# 66  [In HTML some characters are reserved like ,<,...
# 67               [Defines an abbreviation or acronym]
# 68                       [<table style="width:100%">]
# 69                        [<tr style="height:200px">]
# 70        [The <dl> tag defines the description list]
#
# [71 rows x 2 columns]

# %%
for i in df.index:
    df['patterns'][i]= df['patterns'][i][0]
    df['responses'][i]= df['responses'][i][0]

# %%
df
# Out:
#                                patterns  \
# 0                              Hi there
# 1                    What is your name?
# 2                                   Bye
# 3                                Thanks
# 4                  How can you help me?
# ..                                  ...
# 66                what is a html entity
# 67           what does an <abbr> tag do
# 68  how do you set the size of a column
# 69  how do i change the height of a row
# 70           tell me about the <dl> tag
#
#                                             responses
# 0           Hello, I'm sure you will love this course
# 1                                  Hi, I'm  BoTrainer
# 2                                  Have a lovely day!
# 3                                      Happy to help!
# 4   I can answer your questions and clear your mis...
# ..                                                ...
# 66  In HTML some characters are reserved like ,<,>...
# 67                 Defines an abbreviation or acronym
# 68                         <table style="width:100%">
# 69                          <tr style="height:200px">
# 70          The <dl> tag defines the description list
#
# [71 rows x 2 columns]

# %%
for i in df2.index:
    df2['patterns'][i]= df2['patterns'][i][1]
    df2['responses'][i]= df2['responses'][i][0]

# %%
df2
# Out:
#                                      patterns  \
# 0                            Is anyone there?
# 1                               what are you?
# 2                               See you later
# 3                                   Thank you
# 4                            What can you do?
# ..                                        ...
# 66                     what are html entities
# 67                             what is <abbr>
# 68         how can i set the size of a column
# 69  tell me how to change the height of a row
# 70                       what is the <dl> tag
#
#                                             responses
# 0           Hello, I'm sure you will love this course
# 1                                  Hi, I'm  BoTrainer
# 2                                  Have a lovely day!
# 3                                      Happy to help!
# 4   I can answer your questions and clear your mis...
# ..                                                ...
# 66  In HTML some characters are reserved like ,<,>...
# 67                 Defines an abbreviation or acronym
# 68                         <table style="width:100%">
# 69                          <tr style="height:200px">
# 70          The <dl> tag defines the description list
#
# [71 rows x 2 columns]

# %%
for i in df3.index:
    df3['patterns'][i]= df3['patterns'][i][2]
    df3['responses'][i]= df3['responses'][i][0]

# %%
df3
# Out:
#                              patterns  \
# 0                                 Hey
# 1                        who are you?
# 2                             Goodbye
# 3                      That's helpful
# 4              What help you provide?
# ..                                ...
# 66              explain html entities
# 67       tell me about the <abbr> tag
# 68  how do i set the size of a column
# 69   how do i set the height of a row
# 70      what is the <dl> tag used for
#
#                                             responses
# 0           Hello, I'm sure you will love this course
# 1                                  Hi, I'm  BoTrainer
# 2                                  Have a lovely day!
# 3                                      Happy to help!
# 4   I can answer your questions and clear your mis...
# ..                                                ...
# 66  In HTML some characters are reserved like ,<,>...
# 67                 Defines an abbreviation or acronym
# 68                         <table style="width:100%">
# 69                          <tr style="height:200px">
# 70          The <dl> tag defines the description list
#
# [71 rows x 2 columns]

# %%
resultFinal = pd.concat([df, df2,df3], axis=0,ignore_index=True)

# %%
df = resultFinal

# %%
df
# Out:
#                               patterns  \
# 0                             Hi there
# 1                   What is your name?
# 2                                  Bye
# 3                               Thanks
# 4                 How can you help me?
# ..                                 ...
# 208              explain html entities
# 209       tell me about the <abbr> tag
# 210  how do i set the size of a column
# 211   how do i set the height of a row
# 212      what is the <dl> tag used for
#
#                                              responses
# 0            Hello, I'm sure you will love this course
# 1                                   Hi, I'm  BoTrainer
# 2                                   Have a lovely day!
# 3                                       Happy to help!
# 4    I can answer your questions and clear your mis...
# ..                                                 ...
# 208  In HTML some characters are reserved like ,<,>...
# 209                 Defines an abbreviation or acronym
# 210                         <table style="width:100%">
# 211                          <tr style="height:200px">
# 212          The <dl> tag defines the description list
#
# [213 rows x 2 columns]

# %%
df.rename(columns = {'patterns':'Query', 'responses':'Response'}, inplace = True)

# %% [markdown]
# ## Data Understanding

# %%
df.shape
# There are 3724 rows and 2 columns in our dataset
# Out:
# (213, 2)

# %%
df.columns
# Displaying the names of columns present in the dataset
# Out:
# Index(['Query', 'Response'], dtype='object')

# %%
df.info()
# Checking information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Query     213 non-null    object
#  1   Response  213 non-null    object
# dtypes: object(2)
# memory usage: 3.5+ KB

# %%
df.describe()
# Describe function shows us the frequency,unique and counts of all columns
# Out:
#                             Query  \
# count                         213
# unique                        213
# top     what does the <td> tag do
# freq                            1
#
#                                                Response
# count                                               213
# unique                                               71
# top     increases the font size of the text by one unit
# freq                                                  3

# %%
df.nunique()
# nunique() function return number of unique elements in the object.
# Out:
# Query       213
# Response     71
# dtype: int64

# %%
df.isnull().sum()
# Checking for the presence of null values in the data. As we can see there are no null values present in the data
# Out:
# Query       0
# Response    0
# dtype: int64

# %%
df['Query'].value_counts()
# Checking the counts of the values present in the column 'Query'
# Out:
# what does the <td> tag do                           1
# how do i display the content in italics             1
# what does <tr> do                                   1
# how do you join two or more rows in a single row    1
# what does an <abbr> tag do                          1
#                                                    ..
# how do you create a header                          1
# what happens when we use attribute display :none    1
# what does < legend > do                             1
# how do i add background color to a web page         1
# what does < small > do                              1
# Name: Query, Length: 213, dtype: int64

# %%
df['Response'].value_counts()
# Checking the counts of the values present in the column 'Response'
# Out:
# increases the font size of the text by one unit                                                                                                                                                                                                                                                                                                                        3
# Happy to help!                                                                                                                                                                                                                                                                                                                                                         3
# <ol>     </ol>                                                                                                                                                                                                                                                                                                                                                         3
# CSS goes inside the <body> element                                                                                                                                                                                                                                                                                                                                     3
# <ul>     </ul>                                                                                                                                                                                                                                                                                                                                                         3
#                                                                                                                                                                                                                                                                                                                                                                       ..
# decreases the font size of the text by one unit                                                                                                                                                                                                                                                                                                                        3
# The element is an individual component of the HTML web page or document. It represents semantics or meaning. For example, the title element represents the title of the document.and tags are the root of the HTML document which is used to specify that the document is HTML. For example, the Head tag is used to contain all the head element in the HTML file.    3
# <body> tag defines the body of the HTML document. It should always be enclosed in the <html> tag. All the contents which needs to be displayed on the web page like images, text, audio, video, contents, using elements like <p>, <img>, <audio>, <heading>, <video>, <div>, etc.                                                                                     3
# In HTML some characters are reserved like ,<,>, /etc. To use these characters in our webpage we need to use the character entities called HTML Entities. Below are a few mapping between the reserved character and its respective entity character to be used.                                                                                                        3
# <input type="text">                                                                                                                                                                                                                                                                                                                                                    3
# Name: Response, Length: 71, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
Text=df['Query']

# %%
sid = SentimentIntensityAnalyzer()
for sentence in Text:
     print(sentence)
        
     ss = sid.polarity_scores(sentence)
     for k in ss:
         print('{0}: {1}, ' .format(k, ss[k]), end='')
     print()
# Out:
# Hi there
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# What is your name?
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Bye
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Thanks
# neg: 0.0, neu: 0.0, pos: 1.0, compound: 0.4404,
# How can you help me?
# neg: 0.0, neu: 0.597, pos: 0.403, compound: 0.4019,
# what do we call an element without a closing tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what do you call an element that have a closing tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is the difference between a closing and an opening tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i tag an image
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i create a line break
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# how do you create a header
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# how do i add background color to a web page
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how to use bold text
# neg: 0.0, neu: 0.606, pos: 0.394, compound: 0.3818,
# how do i put a text in italic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i create a hyperlink
# neg: 0.0, neu: 0.588, pos: 0.412, compound: 0.2732,
# how do i create html tables
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# what does the <tr> tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the <th> tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the <td> tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can you add a row to a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can you add a header to a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can you add a cell to a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what makes a numbered list
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what makes a unordered list
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i create a checkbox
# neg: 0.0, neu: 0.588, pos: 0.412, compound: 0.2732,
# how do i create an input text field
# neg: 0.0, neu: 0.741, pos: 0.259, compound: 0.2732,
# how do i create a drop-down list
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# how can i add a video file
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i add a audio file
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# which attribute is used to specify the requirement to fill out the input field
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the <nav> tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# where does css in html go
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i add javascript zone in a html document
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i add an area
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i add a button
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i add a caption
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i align my text and center it
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < legend > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < fieldset > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is the class attribute
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < i > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < big > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < small > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < del > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < mark > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is the significance of < head >
# neg: 0.0, neu: 0.704, pos: 0.296, compound: 0.2732,
# what is the significance of < body >
# neg: 0.0, neu: 0.704, pos: 0.296, compound: 0.2732,
# tell me about cell spacing
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me about cell padding
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the easiest way to club two rows together
# neg: 0.0, neu: 0.763, pos: 0.237, compound: 0.4215,
# how can i combine two or more columns in a single column
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what happens if we use attribute visibility :hidden
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what happens if we use attribute display :none
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < a > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what are forms
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i create a web form
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# what does the < figure > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < select > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < datalist > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do semantic elements work
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the < div > tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i resize an image
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is html
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how different are tags and elements
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what's a marquee
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the difference between html and xhtml
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is a html entity
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does an <abbr> tag do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you set the size of a column
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i change the height of a row
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me about the <dl> tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Is anyone there?
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what are you?
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# See you later
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Thank you
# neg: 0.0, neu: 0.286, pos: 0.714, compound: 0.3612,
# What can you do?
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what can we call an element that does not have a closing tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is an element that has a closing tag called
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the difference between a closing tag and an opening tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how should i tag an image
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i make a line break in text
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i make a header
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i add background color
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i put the text in bold
# neg: 0.0, neu: 0.698, pos: 0.302, compound: 0.3818,
# how do i display a text in italic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i create a hyperlink
# neg: 0.0, neu: 0.588, pos: 0.412, compound: 0.2732,
# how can i create tables
# neg: 0.0, neu: 0.588, pos: 0.412, compound: 0.2732,
# what does <tr> do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does <th> do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does <td> do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you add rows in a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you add headers in a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you add cells in a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i make a numbered list
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i make a unordered list
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you make a checkbox
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i create a text field
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# how do you create a drop-down list
# neg: 0.0, neu: 0.704, pos: 0.296, compound: 0.2732,
# how do you add a video file
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you add a audio file
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# which attribute is used to specify that an input field must be filled out
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does <nav> do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# where does css go in html
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# show some ways to add a javascript zone in an html document
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can we add an area
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can we add a button
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can we add a caption
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how to center align text
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < legend > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < fieldset > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is a class
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < i > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < big > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < small > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < del > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < mark > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the meaning of < head >
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the meaning of < body >
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is cell spacing
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is cell padding
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i combine two or more rows in one row
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do we combine two or more columns into one column
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what happens when we use attribute visibility :hidden
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what happens when we use attribute display :none
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < a > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# can you list the forms
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i create a form
# neg: 0.0, neu: 0.588, pos: 0.412, compound: 0.2732,
# what does < figure > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < select > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < datalist > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# can you list the semantic elements
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < div > do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i resize my image
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# define html
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# is there a difference between tags and elements
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is a marquee
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# show the differences between html and xhtml
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what are html entities
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is <abbr>
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i set the size of a column
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me how to change the height of a row
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is the <dl> tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Hey
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# who are you?
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Goodbye
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# That's helpful
# neg: 0.0, neu: 0.263, pos: 0.737, compound: 0.4215,
# What help you provide?
# neg: 0.0, neu: 0.526, pos: 0.474, compound: 0.4019,
# what do you call an element without a closing tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what are elements that contain closing tags called
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the difference between opening and closing tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the best way to tag an image
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.6369,
# how do you create a line break in text
# neg: 0.0, neu: 0.769, pos: 0.231, compound: 0.2732,
# how can i make a header
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how to add background color
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i display the content in bold
# neg: 0.0, neu: 0.698, pos: 0.302, compound: 0.3818,
# how do i display the content in italics
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i make a hyperlink
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do we create a table
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# tell me what does <tr> element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does <th> element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does <td> element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you add a row to a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you add a header to a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you add a cell to a table
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i create a numbered list
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# how can i create a unordered list
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# how do i make a checkbox
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do we create an input text field
# neg: 0.0, neu: 0.769, pos: 0.231, compound: 0.2732,
# how can i create a drop-down list
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# how do i add a video
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i add a audio
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what attribute is used to specify that an input field must be used
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the <nav> element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# where does the css code goes
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how to add a javascript zone in html
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i add an area
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i add a button
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i add a caption
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i center align text
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < legend > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < fieldset > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does a class mean
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < i > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < big > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < small > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < del > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < mark > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < head > mean
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does < body > mean
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# define cell spacing
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# define cell padding
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you join two or more rows in a single row
# neg: 0.0, neu: 0.82, pos: 0.18, compound: 0.296,
# how can i combine two or more columns into one column
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the attribute visibility :hidden do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what does the attribute display :none do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < a > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# define the forms
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do you create form
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.2732,
# tell me what does < figure > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < select > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < datalist > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what are semantic elements
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me what does < div > element do
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how can i resize an image
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# explain html
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me the difference between an element and a tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# can you explain to me what is a marquee
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# list the differences between html and xhtml
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# explain html entities
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# tell me about the <abbr> tag
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i set the size of a column
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# how do i set the height of a row
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# what is the <dl> tag used for
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,

# %%
analyzer = SentimentIntensityAnalyzer()
df['rating'] = Text.apply(analyzer.polarity_scores)
df=pd.concat([df.drop(['rating'], axis=1), df['rating'].apply(pd.Series)], axis=1)
### Creating a dataframe.

# %%
df
# Out:
#                                  Query  \
# 0                             Hi there
# 1                   What is your name?
# 2                                  Bye
# 3                               Thanks
# 4                 How can you help me?
# ..                                 ...
# 208              explain html entities
# 209       tell me about the <abbr> tag
# 210  how do i set the size of a column
# 211   how do i set the height of a row
# 212      what is the <dl> tag used for
#
#                                               Response  neg    neu    pos  \
# 0            Hello, I'm sure you will love this course  0.0  1.000  0.000
# 1                                   Hi, I'm  BoTrainer  0.0  1.000  0.000
# 2                                   Have a lovely day!  0.0  1.000  0.000
# 3                                       Happy to help!  0.0  0.000  1.000
# 4    I can answer your questions and clear your mis...  0.0  0.597  0.403
# ..                                                 ...  ...    ...    ...
# 208  In HTML some characters are reserved like ,<,>...  0.0  1.000  0.000
# 209                 Defines an abbreviation or acronym  0.0  1.000  0.000
# 210                         <table style="width:100%">  0.0  1.000  0.000
# 211                          <tr style="height:200px">  0.0  1.000  0.000
# 212          The <dl> tag defines the description list  0.0  1.000  0.000
#
#      compound
# 0      0.0000
# 1      0.0000
# 2      0.0000
# 3      0.4404
# 4      0.4019
# ..        ...
# 208    0.0000
# 209    0.0000
# 210    0.0000
# 211    0.0000
# 212    0.0000
#
# [213 rows x 6 columns]

# %%
from wordcloud import WordCloud
# importing word cloud

# %%
def wordcloud(df, label):
    
    subset=df[df[label]==1]
    text=df.Query.values
    wc= WordCloud(background_color="black",max_words=1000)

    wc.generate(" ".join(text))

    plt.figure(figsize=(20,20))
    plt.subplot(221)
    plt.axis("off")
    plt.title("Words frequented in {}".format(label), fontsize=20)
    plt.imshow(wc.recolor(colormap= 'gist_earth' , random_state=244), alpha=0.98)
# visualising wordcloud

# %%
wordcloud(df,'Query')
# top words in the query column

# %%
wordcloud(df,'Response')
# top words in the response column

# %% [markdown]
# ## Text-Normalization

# %%
# Removing special characters

# %%
import re
# importing regular expressions

# %%
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())
# Lower case conversion

# %%
remove_n = lambda x: re.sub("\n", " ", x)
# removing \n and replacing them with empty value

# %%
remove_non_ascii = lambda x: re.sub(r'[^\x00-\x7f]',r' ', x)
# removing non ascii characters

# %%
alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
# removing alpha numeric values

# %%
df['Query'] = df['Query'].map(alphanumeric).map(punc_lower).map(remove_n).map(remove_non_ascii)
# using map function and applying the function on query column

# %%
df['Response'] = df['Response'].map(alphanumeric).map(punc_lower).map(remove_n).map(remove_non_ascii)
# using map function and applying the function on response column

# %%
df
# final cleaned dataset
# Out:
#                                  Query  \
# 0                             hi there
# 1                   what is your name
# 2                                  bye
# 3                               thanks
# 4                 how can you help me
# ..                                 ...
# 208              explain html entities
# 209       tell me about the  abbr  tag
# 210  how do i set the size of a column
# 211   how do i set the height of a row
# 212      what is the  dl  tag used for
#
#                                               Response  neg    neu    pos  \
# 0            hello  i m sure you will love this course  0.0  1.000  0.000
# 1                                   hi  i m  botrainer  0.0  1.000  0.000
# 2                                   have a lovely day   0.0  1.000  0.000
# 3                                       happy to help   0.0  0.000  1.000
# 4    i can answer your questions and clear your mis...  0.0  0.597  0.403
# ..                                                 ...  ...    ...    ...
# 208  in html some characters are reserved like     ...  0.0  1.000  0.000
# 209                 defines an abbreviation or acronym  0.0  1.000  0.000
# 210                            table style  width       0.0  1.000  0.000
# 211                               tr style  height      0.0  1.000  0.000
# 212          the  dl  tag defines the description list  0.0  1.000  0.000
#
#      compound
# 0      0.0000
# 1      0.0000
# 2      0.0000
# 3      0.4404
# 4      0.4019
# ..        ...
# 208    0.0000
# 209    0.0000
# 210    0.0000
# 211    0.0000
# 212    0.0000
#
# [213 rows x 6 columns]

# %%
pd.set_option('display.max_rows',3800)
# Displaying all rows in the dataset

# %%
df
# Out:
#                                                  Query  \
# 0                                             hi there
# 1                                   what is your name
# 2                                                  bye
# 3                                               thanks
# 4                                 how can you help me
# 5     what do we call an element without a closing tag
# 6    what do you call an element that have a closin...
# 7    what is the difference between a closing and a...
# 8                                how do i tag an image
# 9                        how can i create a line break
# 10                          how do you create a header
# 11         how do i add background color to a web page
# 12                                how to use bold text
# 13                       how do i put a text in italic
# 14                         how do i create a hyperlink
# 15                         how do i create html tables
# 16                           what does the  tr  tag do
# 17                           what does the  th  tag do
# 18                           what does the  td  tag do
# 19                    how can you add a row to a table
# 20                 how can you add a header to a table
# 21                   how can you add a cell to a table
# 22                          what makes a numbered list
# 23                         what makes a unordered list
# 24                          how do i create a checkbox
# 25                 how do i create an input text field
# 26                    how do i create a drop down list
# 27                          how can i add a video file
# 28                          how can i add a audio file
# 29   which attribute is used to specify the require...
# 30                          what does the  nav  tag do
# 31                           where does css in html go
# 32    how can i add javascript zone in a html document
# 33                                how do i add an area
# 34                               how do i add a button
# 35                              how do i add a caption
# 36               how can i align my text and center it
# 37                     what does the   legend   tag do
# 38                   what does the   fieldset   tag do
# 39                         what is the class attribute
# 40                          what does the   i   tag do
# 41                        what does the   big   tag do
# 42                      what does the   small   tag do
# 43                        what does the   del   tag do
# 44                       what does the   mark   tag do
# 45                what is the significance of   head
# 46                what is the significance of   body
# 47                          tell me about cell spacing
# 48                          tell me about cell padding
# 49   tell me the easiest way to club two rows together
# 50   how can i combine two or more columns in a sin...
# 51   what happens if we use attribute visibility  h...
# 52      what happens if we use attribute display  none
# 53                          what does the   a   tag do
# 54                                      what are forms
# 55                          how do i create a web form
# 56                     what does the   figure   tag do
# 57                     what does the   select   tag do
# 58                   what does the   datalist   tag do
# 59                       how do semantic elements work
# 60                        what does the   div   tag do
# 61                            how do i resize an image
# 62                                        what is html
# 63                 how different are tags and elements
# 64                                    what s a marquee
# 65       tell me the difference between html and xhtml
# 66                               what is a html entity
# 67                          what does an  abbr  tag do
# 68                 how do you set the size of a column
# 69                 how do i change the height of a row
# 70                          tell me about the  dl  tag
# 71                                    is anyone there
# 72                                       what are you
# 73                                       see you later
# 74                                           thank you
# 75                                    what can you do
# 76   what can we call an element that does not have...
# 77    what is an element that has a closing tag called
# 78   tell me the difference between a closing tag a...
# 79                           how should i tag an image
# 80                 how can i make a line break in text
# 81                              how do i make a header
# 82                       how do i add background color
# 83                       how do i put the text in bold
# 84                   how do i display a text in italic
# 85                        how can i create a hyperlink
# 86                             how can i create tables
# 87                                   what does  tr  do
# 88                                   what does  th  do
# 89                                   what does  td  do
# 90                      how do you add rows in a table
# 91                   how do you add headers in a table
# 92                     how do you add cells in a table
# 93                       how do i make a numbered list
# 94                      how do i make a unordered list
# 95                          how do you make a checkbox
# 96                        how do i create a text field
# 97                  how do you create a drop down list
# 98                         how do you add a video file
# 99                         how do you add a audio file
# 100  which attribute is used to specify that an inp...
# 101                                 what does  nav  do
# 102                          where does css go in html
# 103  show some ways to add a javascript zone in an ...
# 104                             how can we add an area
# 105                            how can we add a button
# 106                           how can we add a caption
# 107                           how to center align text
# 108                            what does   legend   do
# 109                          what does   fieldset   do
# 110                                    what is a class
# 111                                 what does   i   do
# 112                               what does   big   do
# 113                             what does   small   do
# 114                               what does   del   do
# 115                              what does   mark   do
# 116                    tell me the meaning of   head
# 117                    tell me the meaning of   body
# 118                               what is cell spacing
# 119                               what is cell padding
# 120       how do i combine two or more rows in one row
# 121  how do we combine two or more columns into one...
# 122  what happens when we use attribute visibility ...
# 123   what happens when we use attribute display  none
# 124                                 what does   a   do
# 125                             can you list the forms
# 126                            how can i create a form
# 127                            what does   figure   do
# 128                            what does   select   do
# 129                          what does   datalist   do
# 130                 can you list the semantic elements
# 131                               what does   div   do
# 132                           how do i resize my image
# 133                                        define html
# 134    is there a difference between tags and elements
# 135                                  what is a marquee
# 136        show the differences between html and xhtml
# 137                             what are html entities
# 138                                     what is  abbr
# 139                 how can i set the size of a column
# 140          tell me how to change the height of a row
# 141                               what is the  dl  tag
# 142                                                hey
# 143                                       who are you
# 144                                            goodbye
# 145                                     that s helpful
# 146                             what help you provide
# 147  what do you call an element without a closing tag
# 148  what are elements that contain closing tags ca...
# 149  tell me the difference between opening and clo...
# 150               tell me the best way to tag an image
# 151             how do you create a line break in text
# 152                            how can i make a header
# 153                        how to add background color
# 154              how can i display the content in bold
# 155            how do i display the content in italics
# 156                         how can i make a hyperlink
# 157                           how do we create a table
# 158                  tell me what does  tr  element do
# 159                  tell me what does  th  element do
# 160                  tell me what does  td  element do
# 161                    how do you add a row to a table
# 162                 how do you add a header to a table
# 163                   how do you add a cell to a table
# 164                   how can i create a numbered list
# 165                  how can i create a unordered list
# 166                           how do i make a checkbox
# 167               how do we create an input text field
# 168                  how can i create a drop down list
# 169                               how do i add a video
# 170                               how do i add a audio
# 171  what attribute is used to specify that an inpu...
# 172                     what does the  nav  element do
# 173                       where does the css code goes
# 174               how to add a javascript zone in html
# 175                              how can i add an area
# 176                             how can i add a button
# 177                            how can i add a caption
# 178                        how can i center align text
# 179            tell me what does   legend   element do
# 180          tell me what does   fieldset   element do
# 181                             what does a class mean
# 182                 tell me what does   i   element do
# 183               tell me what does   big   element do
# 184             tell me what does   small   element do
# 185               tell me what does   del   element do
# 186              tell me what does   mark   element do
# 187                            what does   head   mean
# 188                            what does   body   mean
# 189                                define cell spacing
# 190                                define cell padding
# 191   how do you join two or more rows in a single row
# 192  how can i combine two or more columns into one...
# 193      what does the attribute visibility  hidden do
# 194           what does the attribute display  none do
# 195                 tell me what does   a   element do
# 196                                   define the forms
# 197                             how do you create form
# 198            tell me what does   figure   element do
# 199            tell me what does   select   element do
# 200          tell me what does   datalist   element do
# 201                         what are semantic elements
# 202               tell me what does   div   element do
# 203                          how can i resize an image
# 204                                       explain html
# 205  tell me the difference between an element and ...
# 206            can you explain to me what is a marquee
# 207        list the differences between html and xhtml
# 208                              explain html entities
# 209                       tell me about the  abbr  tag
# 210                  how do i set the size of a column
# 211                   how do i set the height of a row
# 212                      what is the  dl  tag used for
#
#                                               Response  neg    neu    pos  \
# 0            hello  i m sure you will love this course  0.0  1.000  0.000
# 1                                   hi  i m  botrainer  0.0  1.000  0.000
# 2                                   have a lovely day   0.0  1.000  0.000
# 3                                       happy to help   0.0  0.000  1.000
# 4    i can answer your questions and clear your mis...  0.0  0.597  0.403
# 5                                        empty element  0.0  1.000  0.000
# 6                                      closing element  0.0  1.000  0.000
# 7                         closing tag has a   in front  0.0  1.000  0.000
# 8                  img src  image gif  alt  myimage     0.0  1.000  0.000
# 9                                  with the   br   tag  0.0  0.656  0.344
# 10   the     to     tags are used to define html he...  0.0  0.656  0.344
# 11      body style  background color choose a color     0.0  1.000  0.000
# 12                             with the   strong   tag  0.0  0.606  0.394
# 13                                 with the   em   tag  0.0  1.000  0.000
# 14           a href  http   www example com  name  a    0.0  0.588  0.412
# 15               the  table  tag defines an html table  0.0  0.656  0.344
# 16                the  tr  element defines a table row  0.0  1.000  0.000
# 17             the  th  element defines a table header  0.0  1.000  0.000
# 18               the  td  element defines a table cell  0.0  1.000  0.000
# 19                                          tr     tr   0.0  1.000  0.000
# 20                                           th    th   0.0  1.000  0.000
# 21                                           td    td   0.0  1.000  0.000
# 22                                       ol        ol   0.0  1.000  0.000
# 23                                       ul        ul   0.0  1.000  0.000
# 24                            input type  checkbox      0.0  0.588  0.412
# 25                                input type  text      0.0  0.741  0.259
# 26   with  select  and here is an example    select...  0.0  0.656  0.344
# 27                                              video   0.0  1.000  0.000
# 28                                              audio   0.0  1.000  0.000
# 29                         with the required attribute  0.0  1.000  0.000
# 30   the  nav  html element represents a section of...  0.0  1.000  0.000
# 31                  css goes inside the  body  element  0.0  1.000  0.000
# 32    script src      folder name   file name  js  ...  0.0  1.000  0.000
# 33                                                   t  0.0  1.000  0.000
# 34             button type  button  click me   button   0.0  1.000  0.000
# 35   the  caption  tag defines a table caption it m...  0.0  1.000  0.000
# 36                                   with  center  tag  0.0  1.000  0.000
# 37   the  legend  tag defines a caption for the  fi...  0.0  1.000  0.000
# 38   the  fieldset  html element is used to group s...  0.0  1.000  0.000
# 39   the class attribute is used to specify the cla...  0.0  1.000  0.000
# 40                                   makes text italic  0.0  1.000  0.000
# 41     increases the font size of the text by one unit  0.0  1.000  0.000
# 42     decreases the font size of the text by one unit  0.0  1.000  0.000
# 43                         displays as strike out text  0.0  1.000  0.000
# 44                                 highlights the text  0.0  1.000  0.000
# 45    head  tag provides the information about the ...  0.0  0.704  0.296
# 46    body  tag defines the body of the html docume...  0.0  0.704  0.296
# 47   cell spacing is the space or gap between two c...  0.0  1.000  0.000
# 48   cell padding is the space or gap between the t...  0.0  1.000  0.000
# 49                 rowspan    th rowspan     name  th   0.0  0.763  0.237
# 50                 colspan    th colspan     name  th   0.0  1.000  0.000
# 51   when we use the attribute cvisibility  hidden ...  0.0  1.000  0.000
# 52   if we use the cdisplay  none attribute for an ...  0.0  1.000  0.000
# 53   the anchor tag  a  is used to create a hyperli...  0.0  1.000  0.000
# 54   the html form is used to collect the user inpu...  0.0  1.000  0.000
# 55             form action   submit data php     form   0.0  0.656  0.344
# 56   the  figure  tag specifies the self contained ...  0.0  1.000  0.000
# 57    in the case of  select  tag a user will have ...  0.0  1.000  0.000
# 58    datalist  when used along with the  input  ta...  0.0  1.000  0.000
# 59   semantic elements are those which describe the...  0.0  1.000  0.000
# 60                    to logically divide the document  0.0  1.000  0.000
# 61                              using height and width  0.0  1.000  0.000
# 62   html stands for hyper text markup language  it...  0.0  1.000  0.000
# 63   the element is an individual component of the ...  0.0  1.000  0.000
# 64   marquee is used for the scrolling text on a we...  0.0  1.000  0.000
# 65   the differences between html and xhtml are   h...  0.0  1.000  0.000
# 66   in html some characters are reserved like     ...  0.0  1.000  0.000
# 67                  defines an abbreviation or acronym  0.0  1.000  0.000
# 68                             table style  width       0.0  1.000  0.000
# 69                                tr style  height      0.0  1.000  0.000
# 70           the  dl  tag defines the description list  0.0  1.000  0.000
# 71           hello  i m sure you will love this course  0.0  1.000  0.000
# 72                                  hi  i m  botrainer  0.0  1.000  0.000
# 73                                  have a lovely day   0.0  1.000  0.000
# 74                                      happy to help   0.0  0.286  0.714
# 75   i can answer your questions and clear your mis...  0.0  1.000  0.000
# 76                                       empty element  0.0  1.000  0.000
# 77                                     closing element  0.0  1.000  0.000
# 78                        closing tag has a   in front  0.0  1.000  0.000
# 79                 img src  image gif  alt  myimage     0.0  1.000  0.000
# 80                                 with the   br   tag  0.0  1.000  0.000
# 81   the     to     tags are used to define html he...  0.0  1.000  0.000
# 82      body style  background color choose a color     0.0  1.000  0.000
# 83                             with the   strong   tag  0.0  0.698  0.302
# 84                                 with the   em   tag  0.0  1.000  0.000
# 85           a href  http   www example com  name  a    0.0  0.588  0.412
# 86               the  table  tag defines an html table  0.0  0.588  0.412
# 87                the  tr  element defines a table row  0.0  1.000  0.000
# 88             the  th  element defines a table header  0.0  1.000  0.000
# 89               the  td  element defines a table cell  0.0  1.000  0.000
# 90                                          tr     tr   0.0  1.000  0.000
# 91                                           th    th   0.0  1.000  0.000
# 92                                           td    td   0.0  1.000  0.000
# 93                                       ol        ol   0.0  1.000  0.000
# 94                                       ul        ul   0.0  1.000  0.000
# 95                            input type  checkbox      0.0  1.000  0.000
# 96                                input type  text      0.0  0.656  0.344
# 97   with  select  and here is an example    select...  0.0  0.704  0.296
# 98                                              video   0.0  1.000  0.000
# 99                                              audio   0.0  1.000  0.000
# 100                        with the required attribute  0.0  1.000  0.000
# 101  the  nav  html element represents a section of...  0.0  1.000  0.000
# 102                 css goes inside the  body  element  0.0  1.000  0.000
# 103   script src      folder name   file name  js  ...  0.0  1.000  0.000
# 104                                                  t  0.0  1.000  0.000
# 105            button type  button  click me   button   0.0  1.000  0.000
# 106  the  caption  tag defines a table caption it m...  0.0  1.000  0.000
# 107                                  with  center  tag  0.0  1.000  0.000
# 108  the  legend  tag defines a caption for the  fi...  0.0  1.000  0.000
# 109  the  fieldset  html element is used to group s...  0.0  1.000  0.000
# 110  the class attribute is used to specify the cla...  0.0  1.000  0.000
# 111                                  makes text italic  0.0  1.000  0.000
# 112    increases the font size of the text by one unit  0.0  1.000  0.000
# 113    decreases the font size of the text by one unit  0.0  1.000  0.000
# 114                        displays as strike out text  0.0  1.000  0.000
# 115                                highlights the text  0.0  1.000  0.000
# 116   head  tag provides the information about the ...  0.0  1.000  0.000
# 117   body  tag defines the body of the html docume...  0.0  1.000  0.000
# 118  cell spacing is the space or gap between two c...  0.0  1.000  0.000
# 119  cell padding is the space or gap between the t...  0.0  1.000  0.000
# 120                rowspan    th rowspan     name  th   0.0  1.000  0.000
# 121                colspan    th colspan     name  th   0.0  1.000  0.000
# 122  when we use the attribute cvisibility  hidden ...  0.0  1.000  0.000
# 123  if we use the cdisplay  none attribute for an ...  0.0  1.000  0.000
# 124  the anchor tag  a  is used to create a hyperli...  0.0  1.000  0.000
# 125  the html form is used to collect the user inpu...  0.0  1.000  0.000
# 126            form action   submit data php     form   0.0  0.588  0.412
# 127  the  figure  tag specifies the self contained ...  0.0  1.000  0.000
# 128   in the case of  select  tag a user will have ...  0.0  1.000  0.000
# 129   datalist  when used along with the  input  ta...  0.0  1.000  0.000
# 130  semantic elements are those which describe the...  0.0  1.000  0.000
# 131                   to logically divide the document  0.0  1.000  0.000
# 132                             using height and width  0.0  1.000  0.000
# 133  html stands for hyper text markup language  it...  0.0  1.000  0.000
# 134  the element is an individual component of the ...  0.0  1.000  0.000
# 135  marquee is used for the scrolling text on a we...  0.0  1.000  0.000
# 136  the differences between html and xhtml are   h...  0.0  1.000  0.000
# 137  in html some characters are reserved like     ...  0.0  1.000  0.000
# 138                 defines an abbreviation or acronym  0.0  1.000  0.000
# 139                            table style  width       0.0  1.000  0.000
# 140                               tr style  height      0.0  1.000  0.000
# 141          the  dl  tag defines the description list  0.0  1.000  0.000
# 142          hello  i m sure you will love this course  0.0  1.000  0.000
# 143                                 hi  i m  botrainer  0.0  1.000  0.000
# 144                                 have a lovely day   0.0  1.000  0.000
# 145                                     happy to help   0.0  0.263  0.737
# 146  i can answer your questions and clear your mis...  0.0  0.526  0.474
# 147                                      empty element  0.0  1.000  0.000
# 148                                    closing element  0.0  1.000  0.000
# 149                       closing tag has a   in front  0.0  1.000  0.000
# 150                img src  image gif  alt  myimage     0.0  0.656  0.344
# 151                                with the   br   tag  0.0  0.769  0.231
# 152  the     to     tags are used to define html he...  0.0  1.000  0.000
# 153     body style  background color choose a color     0.0  1.000  0.000
# 154                            with the   strong   tag  0.0  0.698  0.302
# 155                                with the   em   tag  0.0  1.000  0.000
# 156          a href  http   www example com  name  a    0.0  1.000  0.000
# 157              the  table  tag defines an html table  0.0  0.656  0.344
# 158               the  tr  element defines a table row  0.0  1.000  0.000
# 159            the  th  element defines a table header  0.0  1.000  0.000
# 160              the  td  element defines a table cell  0.0  1.000  0.000
# 161                                         tr     tr   0.0  1.000  0.000
# 162                                          th    th   0.0  1.000  0.000
# 163                                          td    td   0.0  1.000  0.000
# 164                                      ol        ol   0.0  0.656  0.344
# 165                                      ul        ul   0.0  0.656  0.344
# 166                           input type  checkbox      0.0  1.000  0.000
# 167                               input type  text      0.0  0.769  0.231
# 168  with  select  and here is an example    select...  0.0  0.656  0.344
# 169                                             video   0.0  1.000  0.000
# 170                                             audio   0.0  1.000  0.000
# 171                        with the required attribute  0.0  1.000  0.000
# 172  the  nav  html element represents a section of...  0.0  1.000  0.000
# 173                 css goes inside the  body  element  0.0  1.000  0.000
# 174   script src      folder name   file name  js  ...  0.0  1.000  0.000
# 175                                                  t  0.0  1.000  0.000
# 176            button type  button  click me   button   0.0  1.000  0.000
# 177  the  caption  tag defines a table caption it m...  0.0  1.000  0.000
# 178                                  with  center  tag  0.0  1.000  0.000
# 179  the  legend  tag defines a caption for the  fi...  0.0  1.000  0.000
# 180  the  fieldset  html element is used to group s...  0.0  1.000  0.000
# 181  the class attribute is used to specify the cla...  0.0  1.000  0.000
# 182                                  makes text italic  0.0  1.000  0.000
# 183    increases the font size of the text by one unit  0.0  1.000  0.000
# 184    decreases the font size of the text by one unit  0.0  1.000  0.000
# 185                        displays as strike out text  0.0  1.000  0.000
# 186                                highlights the text  0.0  1.000  0.000
# 187   head  tag provides the information about the ...  0.0  1.000  0.000
# 188   body  tag defines the body of the html docume...  0.0  1.000  0.000
# 189  cell spacing is the space or gap between two c...  0.0  1.000  0.000
# 190  cell padding is the space or gap between the t...  0.0  1.000  0.000
# 191                rowspan    th rowspan     name  th   0.0  0.820  0.180
# 192                colspan    th colspan     name  th   0.0  1.000  0.000
# 193  when we use the attribute cvisibility  hidden ...  0.0  1.000  0.000
# 194  if we use the cdisplay  none attribute for an ...  0.0  1.000  0.000
# 195  the anchor tag  a  is used to create a hyperli...  0.0  1.000  0.000
# 196  the html form is used to collect the user inpu...  0.0  1.000  0.000
# 197            form action   submit data php     form   0.0  0.656  0.344
# 198  the  figure  tag specifies the self contained ...  0.0  1.000  0.000
# 199   in the case of  select  tag a user will have ...  0.0  1.000  0.000
# 200   datalist  when used along with the  input  ta...  0.0  1.000  0.000
# 201  semantic elements are those which describe the...  0.0  1.000  0.000
# 202                   to logically divide the document  0.0  1.000  0.000
# 203                             using height and width  0.0  1.000  0.000
# 204  html stands for hyper text markup language  it...  0.0  1.000  0.000
# 205  the element is an individual component of the ...  0.0  1.000  0.000
# 206  marquee is used for the scrolling text on a we...  0.0  1.000  0.000
# 207  the differences between html and xhtml are   h...  0.0  1.000  0.000
# 208  in html some characters are reserved like     ...  0.0  1.000  0.000
# 209                 defines an abbreviation or acronym  0.0  1.000  0.000
# 210                            table style  width       0.0  1.000  0.000
# 211                               tr style  height      0.0  1.000  0.000
# 212          the  dl  tag defines the description list  0.0  1.000  0.000
#
#      compound
# 0      0.0000
# 1      0.0000
# 2      0.0000
# 3      0.4404
# 4      0.4019
# 5      0.0000
# 6      0.0000
# 7      0.0000
# 8      0.0000
# 9      0.2732
# 10     0.2732
# 11     0.0000
# 12     0.3818
# 13     0.0000
# 14     0.2732
# 15     0.2732
# 16     0.0000
# 17     0.0000
# 18     0.0000
# 19     0.0000
# 20     0.0000
# 21     0.0000
# 22     0.0000
# 23     0.0000
# 24     0.2732
# 25     0.2732
# 26     0.2732
# 27     0.0000
# 28     0.0000
# 29     0.0000
# 30     0.0000
# 31     0.0000
# 32     0.0000
# 33     0.0000
# 34     0.0000
# 35     0.0000
# 36     0.0000
# 37     0.0000
# 38     0.0000
# 39     0.0000
# 40     0.0000
# 41     0.0000
# 42     0.0000
# 43     0.0000
# 44     0.0000
# 45     0.2732
# 46     0.2732
# 47     0.0000
# 48     0.0000
# 49     0.4215
# 50     0.0000
# 51     0.0000
# 52     0.0000
# 53     0.0000
# 54     0.0000
# 55     0.2732
# 56     0.0000
# 57     0.0000
# 58     0.0000
# 59     0.0000
# 60     0.0000
# 61     0.0000
# 62     0.0000
# 63     0.0000
# 64     0.0000
# 65     0.0000
# 66     0.0000
# 67     0.0000
# 68     0.0000
# 69     0.0000
# 70     0.0000
# 71     0.0000
# 72     0.0000
# 73     0.0000
# 74     0.3612
# 75     0.0000
# 76     0.0000
# 77     0.0000
# 78     0.0000
# 79     0.0000
# 80     0.0000
# 81     0.0000
# 82     0.0000
# 83     0.3818
# 84     0.0000
# 85     0.2732
# 86     0.2732
# 87     0.0000
# 88     0.0000
# 89     0.0000
# 90     0.0000
# 91     0.0000
# 92     0.0000
# 93     0.0000
# 94     0.0000
# 95     0.0000
# 96     0.2732
# 97     0.2732
# 98     0.0000
# 99     0.0000
# 100    0.0000
# 101    0.0000
# 102    0.0000
# 103    0.0000
# 104    0.0000
# 105    0.0000
# 106    0.0000
# 107    0.0000
# 108    0.0000
# 109    0.0000
# 110    0.0000
# 111    0.0000
# 112    0.0000
# 113    0.0000
# 114    0.0000
# 115    0.0000
# 116    0.0000
# 117    0.0000
# 118    0.0000
# 119    0.0000
# 120    0.0000
# 121    0.0000
# 122    0.0000
# 123    0.0000
# 124    0.0000
# 125    0.0000
# 126    0.2732
# 127    0.0000
# 128    0.0000
# 129    0.0000
# 130    0.0000
# 131    0.0000
# 132    0.0000
# 133    0.0000
# 134    0.0000
# 135    0.0000
# 136    0.0000
# 137    0.0000
# 138    0.0000
# 139    0.0000
# 140    0.0000
# 141    0.0000
# 142    0.0000
# 143    0.0000
# 144    0.0000
# 145    0.4215
# 146    0.4019
# 147    0.0000
# 148    0.0000
# 149    0.0000
# 150    0.6369
# 151    0.2732
# 152    0.0000
# 153    0.0000
# 154    0.3818
# 155    0.0000
# 156    0.0000
# 157    0.2732
# 158    0.0000
# 159    0.0000
# 160    0.0000
# 161    0.0000
# 162    0.0000
# 163    0.0000
# 164    0.2732
# 165    0.2732
# 166    0.0000
# 167    0.2732
# 168    0.2732
# 169    0.0000
# 170    0.0000
# 171    0.0000
# 172    0.0000
# 173    0.0000
# 174    0.0000
# 175    0.0000
# 176    0.0000
# 177    0.0000
# 178    0.0000
# 179    0.0000
# 180    0.0000
# 181    0.0000
# 182    0.0000
# 183    0.0000
# 184    0.0000
# 185    0.0000
# 186    0.0000
# 187    0.0000
# 188    0.0000
# 189    0.0000
# 190    0.0000
# 191    0.2960
# 192    0.0000
# 193    0.0000
# 194    0.0000
# 195    0.0000
# 196    0.0000
# 197    0.2732
# 198    0.0000
# 199    0.0000
# 200    0.0000
# 201    0.0000
# 202    0.0000
# 203    0.0000
# 204    0.0000
# 205    0.0000
# 206    0.0000
# 207    0.0000
# 208    0.0000
# 209    0.0000
# 210    0.0000
# 211    0.0000
# 212    0.0000

# %% [markdown]
# ### Important Sentence

# %%
imp_sent=df.sort_values(by='compound', ascending=False)
# arranging the compound column in descending order to find the best sentence.

# %%
imp_sent.head(5)
# printing the first 5 rows
# Out:
#                                                  Query  \
# 150               tell me the best way to tag an image
# 3                                               thanks
# 145                                     that s helpful
# 49   tell me the easiest way to club two rows together
# 4                                 how can you help me
#
#                                               Response  neg    neu    pos  \
# 150                img src  image gif  alt  myimage     0.0  0.656  0.344
# 3                                       happy to help   0.0  0.000  1.000
# 145                                     happy to help   0.0  0.263  0.737
# 49                 rowspan    th rowspan     name  th   0.0  0.763  0.237
# 4    i can answer your questions and clear your mis...  0.0  0.597  0.403
#
#      compound
# 150    0.6369
# 3      0.4404
# 145    0.4215
# 49     0.4215
# 4      0.4019

# %% [markdown]
# ### Top Positive Sentence

# %%
pos_sent=df.sort_values(by='pos', ascending=False)
# Arranging the dataframe by positive column in descending order to find the best postive sentence.

# %%
pos_sent.head(5)
# printing the first 5 rows
# Out:
#                             Query  \
# 3                          thanks
# 145                that s helpful
# 74                      thank you
# 146        what help you provide
# 85   how can i create a hyperlink
#
#                                               Response  neg    neu    pos  \
# 3                                       happy to help   0.0  0.000  1.000
# 145                                     happy to help   0.0  0.263  0.737
# 74                                      happy to help   0.0  0.286  0.714
# 146  i can answer your questions and clear your mis...  0.0  0.526  0.474
# 85           a href  http   www example com  name  a    0.0  0.588  0.412
#
#      compound
# 3      0.4404
# 145    0.4215
# 74     0.3612
# 146    0.4019
# 85     0.2732

# %% [markdown]
# ### Top Negative Sentence

# %%
neg_sent=df.sort_values(by='neg', ascending=False)
# Arranging the dataframe by negative column in descending order to find the best negative sentence.

# %%
neg_sent.head(5)
# printing the first 5 rows
# Out:
#                                                Query  \
# 0                                           hi there
# 134  is there a difference between tags and elements
# 136      show the differences between html and xhtml
# 137                           what are html entities
# 138                                   what is  abbr
#
#                                               Response  neg  neu  pos  \
# 0            hello  i m sure you will love this course  0.0  1.0  0.0
# 134  the element is an individual component of the ...  0.0  1.0  0.0
# 136  the differences between html and xhtml are   h...  0.0  1.0  0.0
# 137  in html some characters are reserved like     ...  0.0  1.0  0.0
# 138                 defines an abbreviation or acronym  0.0  1.0  0.0
#
#      compound
# 0         0.0
# 134       0.0
# 136       0.0
# 137       0.0
# 138       0.0

# %% [markdown]
# ### Top Neutral Sentence

# %%
neu_sent=df.sort_values(by='neu', ascending=False)
# Arranging the dataframe by negative column in descending order to find the best neutral sentence.

# %%
neu_sent.head(5)
# printing the first 5 rows
# Out:
#                                   Query  \
# 0                              hi there
# 138                      what is  abbr
# 128             what does   select   do
# 129           what does   datalist   do
# 130  can you list the semantic elements
#
#                                               Response  neg  neu  pos  \
# 0            hello  i m sure you will love this course  0.0  1.0  0.0
# 138                 defines an abbreviation or acronym  0.0  1.0  0.0
# 128   in the case of  select  tag a user will have ...  0.0  1.0  0.0
# 129   datalist  when used along with the  input  ta...  0.0  1.0  0.0
# 130  semantic elements are those which describe the...  0.0  1.0  0.0
#
#      compound
# 0         0.0
# 138       0.0
# 128       0.0
# 129       0.0
# 130       0.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# importing tfidf vectorizer

# %%
tfidf = TfidfVectorizer()
# Word Embedding - TF-IDF

# %%
factors = tfidf.fit_transform(df['Query']).toarray()
# changing column into array

# %%
tfidf.get_feature_names()
# displaying feature names
# Out:
# ['abbr',
#  'about',
#  'add',
#  'align',
#  'an',
#  'and',
#  'anyone',
#  'are',
#  'area',
#  'attribute',
#  'audio',
#  'background',
#  'be',
#  'best',
#  'between',
#  'big',
#  'body',
#  'bold',
#  'break',
#  'button',
#  'bye',
#  'call',
#  'called',
#  'can',
#  'caption',
#  'cell',
#  'cells',
#  'center',
#  'change',
#  'checkbox',
#  'class',
#  'closing',
#  'club',
#  'code',
#  'color',
#  'column',
#  'columns',
#  'combine',
#  'contain',
#  'content',
#  'create',
#  'css',
#  'datalist',
#  'define',
#  'del',
#  'difference',
#  'differences',
#  'different',
#  'display',
#  'div',
#  'dl',
#  'do',
#  'document',
#  'does',
#  'down',
#  'drop',
#  'easiest',
#  'element',
#  'elements',
#  'entities',
#  'entity',
#  'explain',
#  'field',
#  'fieldset',
#  'figure',
#  'file',
#  'fill',
#  'filled',
#  'for',
#  'form',
#  'forms',
#  'go',
#  'goes',
#  'goodbye',
#  'happens',
#  'has',
#  'have',
#  'head',
#  'header',
#  'headers',
#  'height',
#  'help',
#  'helpful',
#  'hey',
#  'hi',
#  'hidden',
#  'how',
#  'html',
#  'hyperlink',
#  'if',
#  'image',
#  'in',
#  'input',
#  'into',
#  'is',
#  'it',
#  'italic',
#  'italics',
#  'javascript',
#  'join',
#  'later',
#  'legend',
#  'line',
#  'list',
#  'make',
#  'makes',
#  'mark',
#  'marquee',
#  'me',
#  'mean',
#  'meaning',
#  'more',
#  'must',
#  'my',
#  'name',
#  'nav',
#  'none',
#  'not',
#  'numbered',
#  'of',
#  'one',
#  'opening',
#  'or',
#  'out',
#  'padding',
#  'page',
#  'provide',
#  'put',
#  'requirement',
#  'resize',
#  'row',
#  'rows',
#  'see',
#  'select',
#  'semantic',
#  'set',
#  'should',
#  'show',
#  'significance',
#  'single',
#  'size',
#  'small',
#  'some',
#  'spacing',
#  'specify',
#  'table',
#  'tables',
#  'tag',
#  'tags',
#  'td',
#  'tell',
#  'text',
#  'th',
#  'thank',
#  'thanks',
#  'that',
#  'the',
#  'there',
#  'to',
#  'together',
#  'tr',
#  'two',
#  'unordered',
#  'use',
#  'used',
#  'video',
#  'visibility',
#  'way',
#  'ways',
#  'we',
#  'web',
#  'what',
#  'when',
#  'where',
#  'which',
#  'who',
#  'without',
#  'work',
#  'xhtml',
#  'you',
#  'your',
#  'zone']

# %% [markdown]
# # Application

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
query = 'who are you ?'
def chatbot(query):
    # step:-1 clean
    query = nu.lemmatization_sentence(query)
    # step:-2 word embedding - transform
    query_vector = tfidf.transform([query]).toarray()
    # step-3: cosine similarity
    similar_score = 1 -cosine_distances(factors,query_vector)
    index = similar_score.argmax() # take max index position
    # searching or matching question
    matching_question = df.loc[index]['Query']
    response = df.loc[index]['Response']
    pos_score = df.loc[index]['pos']
    neg_score = df.loc[index]['neg']
    neu_score = df.loc[index]['neu']
    confidence = similar_score[index][0]
    chat_dict = {'match':matching_question,
                'response':response,
                'score':confidence,
                'pos':pos_score,
                'neg':neg_score,
                'neu':neu_score}
    return chat_dict

# %%
while True:
    query = input('USER: ')
    if query == 'exit':
        break
        
    response = chatbot(query)
    if response['score'] <= 0.2: # 
        print('BOT: Please rephrase your Question.')
    
    else:
        print('='*80)
        print('logs:\n Matched Question: %r\n Confidence Score: %0.2f \n PositiveScore: %r \n NegativeScore: %r\n NeutralScore: %r'%(
            response['match'],response['score']*100,response['pos'],response['neg'],response['neu']))
        print('='*80)
        print('BOT: ',response['response'])
# Out:
# USER: hi there
# ================================================================================
# logs:
#  Matched Question: 'hi there'
#  Confidence Score: 100.00
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:  hello  i m sure you will love this course
# USER: hey
# ================================================================================
# logs:
#  Matched Question: 'hey'
#  Confidence Score: 100.00
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:  hello  i m sure you will love this course
# USER: hello
# BOT: Please rephrase your Question.
# USER: hey dude
# ================================================================================
# logs:
#  Matched Question: 'hey'
#  Confidence Score: 100.00
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:  hello  i m sure you will love this course
# USER: what is html
# ================================================================================
# logs:
#  Matched Question: 'what is html'
#  Confidence Score: 47.39
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:  html stands for hyper text markup language  it is a language of the world wide web  it is a standard text formatting language which is used to create and display pages on the web  html makes the text more interactive and dynamic  it can turn text into images  tables  links  html pages are saved by adding  html or  html in web page name
# USER: explain html
# ================================================================================
# logs:
#  Matched Question: 'explain html'
#  Confidence Score: 100.00
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:  html stands for hyper text markup language  it is a language of the world wide web  it is a standard text formatting language which is used to create and display pages on the web  html makes the text more interactive and dynamic  it can turn text into images  tables  links  html pages are saved by adding  html or  html in web page name
# USER: what does select do
# ================================================================================
# logs:
#  Matched Question: 'what does   select   do'
#  Confidence Score: 89.40
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:   in the case of  select  tag a user will have to choose from a list of options
# USER: select ?
# ================================================================================
# logs:
#  Matched Question: 'what does   select   do'
#  Confidence Score: 82.45
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:   in the case of  select  tag a user will have to choose from a list of options
# USER: what is select tag
# ================================================================================
# logs:
#  Matched Question: 'what does the   select   tag do'
#  Confidence Score: 63.96
#  PositiveScore: 0.0
#  NegativeScore: 0.0
#  NeutralScore: 1.0
# ================================================================================
# BOT:   in the case of  select  tag a user will have to choose from a list of options
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-127-d58d39b92d10> in <module>
#       1 while True:
# ----> 2     query = input('USER: ')
#       3     if query == 'exit':
#       4         break
#       5
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
